# %% [markdown]
# # Ejercicios de probabilidad

# %% [markdown]
# ## Ejercicio 1
#
# Dos dados se lanzan una vez y se observa el total obtenido. Usa una simulación para encontrar la probabilidad estimada de que la puntuación sea mayor a 7 o un número par. Una simulación es una repetición del mismo experimento multiples veces para observar su comportamiento:
#
# - Ejecuta el experimento 1000 veces (lanza 2 dados 1000 veces, y suma el número de ambos dados).
# - Lleva ua cuenta de los números y las veces que la suma fue mayor a 7 o un número par.
# - Divide el número del paso 2 entre el número de iteraciones(1000).

# %%
# Importar librería
import numpy as np
import matplotlib.pyplot as plt

# Ejecuta el experimento 1000 veces (lanza 2 dados 1000 veces, y suma el número de ambos dados).
n=1000
dado_1=(np.random.randint(1,7,n))
dado_2=(np.random.randint(1,7,n))
dado_suma=dado_1+dado_2
#print(dado_suma)

#Lleva una cuenta de los números y las veces que la suma fue mayor a 7 (suceso A) o un número par (suceso B) -> A u B
Num_eventos_AuB=0
Eventos_AuB=[]
for i in dado_suma:
    if (i > 7) or (i % 2) == 0:
        Num_eventos_AuB += 1
        Eventos_AuB.append(i)
print("El número de eventos con éxito par la unión A u B es : " + str(Num_eventos_AuB))

# Divide el número del paso 2 entre el número de iteraciones(1000) -> P(A u B)
P_AuB = Num_eventos_AuB/n
print("La probabilidad de la únion de eventos A u B es: " + str(round(P_AuB*100,2)) + " %")

# Plotea los datos y la probabilidad
plt.figure(figsize = (8, 4))
bins = np.arange(2,14) - 0.5
xticks = np.arange(2,13)
values, bins, bars = plt.hist(dado_suma,bins=bins, edgecolor='black', linewidth=1, rwidth=0.5, color="red")
plt.hist(Eventos_AuB,bins=bins, edgecolor='black',  linewidth=1, rwidth=0.5, color="lightgreen", label="Eventos dentro de AuB")
plt.xlabel("Suma de ambos dados")
plt.ylabel("Conteo")
plt.bar_label(bars, fontsize=10, color='black')
plt.legend()
plt.title("Experimento Dados Locos")
plt.xticks(xticks)
plt.show() 

plt.figure(figsize = (8,4))
plt.title("Porcentaje de éxitos")
plt.pie((Num_eventos_AuB,n-Num_eventos_AuB),autopct='%1.0f%%', colors=("lightgreen", "red"))
plt.show()
# Out:
# El número de eventos con éxito par la unión A u B es : 688
# La probabilidad de la únion de eventos A u B es: 68.8 %

# %% [markdown]
# ## Ejercicio 2
#
# Una caja contiene 10 bolas blancas, 20 bolas rojas y 30 bolas verdes. Si tomamos 5 bolas de la caja reemplazándolas (tomando una bola, anotando el color y luego regresandola a la caja). Queremos saber la probabilidad de:
#
# 1. Tomar 3 blancas y 2 rojas.
# 2. Toas todas del mismo color.
#
# Ejecuta el experimento 1000 veces y calcula las probabilidades que mencionadas.

# %%
ball_box = {}

# Crea la cajas con las bolas
for i in range(60):
    if i < 10:
        ball_box[i] = "White"
    elif (i > 9) and (i < 30):
        ball_box[i] = "Red"
    else:
        ball_box[i] = "Green"
# Número de simulaciones
no_sim=1000

# Inicializar variable cumulativa para éxitos
conteo_1 = 0
conteo_2 = 0

#Repetir el experimento n_sim veces
for s in range(no_sim):
    muestra_white = 0
    muestra_red = 0
    muestra_green = 0
    #Coger una bola random 5 veces
    for i in range(5):
        num_seleccionado = np.random.randint(0,59)
        color_seleccionado = ball_box[num_seleccionado]
        if color_seleccionado == "White":
            muestra_white += 1
        elif color_seleccionado =="Red":
            muestra_red += 1
        else:
            muestra_green += 1
    if muestra_white >= 3 and muestra_red >= 2:
        conteo_1 += 1
    if muestra_white == 5 or muestra_red == 5 or muestra_green == 5:
        conteo_2 += 1

#Calcular probabilidades de cada caso (éxitos/no_experimentos)          
prob_1=conteo_1/no_sim
prob_2=conteo_2/no_sim

print("La probabilidad de sacar 3 bolas blancas y 2 rojas es: " + str(round(prob_1*100,5)) + " %")
print("La probabilidad de sacar todas las bolas (5) del mismo color es: " + str(round(prob_2*100,5)) + " %")
# Out:
# La probabilidad de sacar 3 bolas blancas y 2 rojas es: 0.1 %
# La probabilidad de sacar todas las bolas (5) del mismo color es: 3.6 %
